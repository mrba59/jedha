# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("Speed+Dating+Data.csv", encoding = "unicode-escape'" )
len(df.columns)
# Out:
# 195

# %%
df.iloc[:,0:20].describe()
# Out:
#                iid           id       gender          idg       condtn  \
# count  8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# mean    283.675937     8.960248     0.500597    17.327166     1.828837
# std     158.583367     5.491329     0.500029    10.940735     0.376673
# min       1.000000     1.000000     0.000000     1.000000     1.000000
# 25%     154.000000     4.000000     0.000000     8.000000     2.000000
# 50%     281.000000     8.000000     1.000000    16.000000     2.000000
# 75%     407.000000    13.000000     1.000000    26.000000     2.000000
# max     552.000000    22.000000     1.000000    44.000000     2.000000
#
#               wave        round     position     positin1        order  \
# count  8378.000000  8378.000000  8378.000000  6532.000000  8378.000000
# mean     11.350919    16.872046     9.042731     9.295775     8.927668
# std       5.995903     4.358458     5.514939     5.650199     5.477009
# ...

# %%
df.iloc[:,20:40].describe()
# Out:
#           pf_o_fun     pf_o_amb     pf_o_sha        dec_o       attr_o  \
# count  8280.000000  8271.000000  8249.000000  8378.000000  8166.000000
# mean     17.459714    10.685375    11.845930     0.419551     6.190411
# std       6.085526     6.126544     6.362746     0.493515     1.950305
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      15.000000     5.000000     9.520000     0.000000     5.000000
# 50%      18.000000    10.000000    10.640000     0.000000     6.000000
# 75%      20.000000    15.000000    16.000000     1.000000     8.000000
# max      50.000000    53.000000    30.000000     1.000000    10.500000
#
#             sinc_o      intel_o        fun_o        amb_o       shar_o  \
# count  8091.000000  8072.000000  8018.000000  7656.000000  7302.000000
# mean      7.175256     7.369301     6.400599     6.778409     5.474870
# std       1.740575     1.550501     1.954078     1.794080     2.156163
# ...

# %%
df.iloc[:,40:60].describe()
# Out:
#            imprace     imprelig         goal         date       go_out  \
# count  8299.000000  8299.000000  8299.000000  8281.000000  8299.000000
# mean      3.784793     3.651645     2.122063     5.006762     2.158091
# std       2.845708     2.805237     1.407181     1.444531     1.105246
# min       0.000000     1.000000     1.000000     1.000000     1.000000
# 25%       1.000000     1.000000     1.000000     4.000000     1.000000
# 50%       3.000000     3.000000     2.000000     5.000000     2.000000
# 75%       6.000000     6.000000     2.000000     6.000000     3.000000
# max      10.000000    10.000000     6.000000     7.000000     7.000000
#
#           career_c       sports     tvsports     exercise       dining  \
# count  8240.000000  8299.000000  8299.000000  8299.000000  8299.000000
# mean      5.277791     6.425232     4.575491     6.245813     7.783829
# std       3.309520     2.619024     2.801874     2.418858     1.754868
# ...

# %%
df.iloc[:,60:80].describe()
# Out:
#                 tv      theater       movies     concerts        music  \
# count  8299.000000  8299.000000  8299.000000  8299.000000  8299.000000
# mean      5.304133     6.776118     7.919629     6.825401     7.851066
# std       2.529135     2.235152     1.700927     2.156283     1.791827
# min       1.000000     0.000000     0.000000     0.000000     1.000000
# 25%       3.000000     5.000000     7.000000     5.000000     7.000000
# 50%       6.000000     7.000000     8.000000     7.000000     8.000000
# 75%       7.000000     9.000000     9.000000     8.000000     9.000000
# max      10.000000    10.000000    10.000000    10.000000    10.000000
#
#           shopping         yoga     exphappy       expnum      attr1_1  \
# count  8299.000000  8299.000000  8277.000000  1800.000000  8299.000000
# mean      5.631281     4.339197     5.534131     5.570556    22.514632
# std       2.608913     2.717612     1.734059     4.762569    12.587674
# ...

# %% [markdown]
# ### Relation between match and corr interest

# %%
sns.lmplot(x="int_corr", y="match", data =df, logistic=True, scatter_kws={"alpha":.05})

# %%
df_rated_act = df.groupby("iid")[["gender","sports","tvsports","exercise","dining","museums","art","hiking","gaming","clubbing","reading","tv","theater","movies","concerts","music","shopping","yoga"]].max()
df_rated_act
# Out:
#      gender  sports  tvsports  exercise  dining  museums   art  hiking  \
# iid
# 1         0     9.0       2.0       8.0     9.0      1.0   1.0     5.0
# 2         0     3.0       2.0       7.0    10.0      8.0   6.0     3.0
# 3         0     3.0       8.0       7.0     8.0      5.0   5.0     8.0
# 4         0     1.0       1.0       6.0     7.0      6.0   7.0     7.0
# 5         0     7.0       4.0       7.0     7.0      6.0   8.0     6.0
# ..      ...     ...       ...       ...     ...      ...   ...     ...
# 548       1    10.0       8.0       4.0    10.0      3.0   2.0     2.0
# 549       1     8.0       5.0       6.0     9.0      7.0   7.0     4.0
# 550       1     5.0       3.0       5.0     9.0      7.0   8.0     3.0
# 551       1     6.0       1.0       7.0     6.0      7.0   3.0     2.0
# 552       1     8.0       2.0       5.0    10.0     10.0  10.0     7.0
#
#      gaming  clubbing  reading   tv  theater  movies  concerts  music  \
# iid
# ...

# %%
sea = sns.FacetGrid(df_rated_act, col = "time", height = 4)
sns.boxplot(data = df_rated_act, y="sports", x="gender")
# Out:
# <Axes: xlabel='gender', ylabel='sports'>

# %%
# idee relation between match and same field study , crete coloun same_field
# evaluer l'attribut que els hommes recherhe le plus
# pareil femme

# %%
df_corr_match = df.corr(numeric_only=True)["match"]
df_corr_match.loc[lambda x: x>0.25].sort_values(ascending=False)
# Out:
# match     1.000000
# dec_o     0.522326
# dec       0.521943
# like_o    0.305853
# like      0.305723
# fun_o     0.277700
# fun       0.277545
# shar_o    0.270840
# shar      0.270679
# attr_o    0.260837
# attr      0.260676
# prob_o    0.255574
# prob      0.255531
# Name: match, dtype: float64

# %%
df
